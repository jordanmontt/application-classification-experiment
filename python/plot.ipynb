# %%
from processor import *
from scipy.stats import ks_2samp, kstest
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df_1, metadata_df1 = load_df('/Users/sebastian/Documents/PharoImages/new-2024/2024-01-25H12m32-df1.csv', '/Users/sebastian/Documents/PharoImages/new-2024/2024-01-25H12m32.json')

# %%
df_100, metadata_df100 = load_df('/Users/sebastian/Documents/PharoImages/new-2024/2024-01-25H12m25-df100.csv', '/Users/sebastian/Documents/PharoImages/new-2024/2024-01-25H12m25.json')

# %%
df_50, metadata_df50 = load_df('/Users/sebastian/Documents/PharoImages/new-2024/2024-01-29H12m45-df50.csv', '/Users/sebastian/Documents/PharoImages/new-2024/2024-01-29H12m45.json')

# %%
sns.histplot(df_1['relativeSurvivedGCCycles'], stat="percent", bins=20)
# Out:
# <Axes: xlabel='relativeSurvivedGCCycles', ylabel='Percent'>

# %%
sns.histplot(df_100['relativeSurvivedGCCycles'], stat="percent", bins=20)
# Out:
# <Axes: xlabel='relativeSurvivedGCCycles', ylabel='Percent'>

# %%
sns.histplot(df_100.groupby('allocatedObjectClass').get_group('ByteString')['relativeSurvivedGCCycles'], stat="percent", bins=20)
# Out:
# <Axes: xlabel='relativeSurvivedGCCycles', ylabel='Percent'>

# %%
sns.histplot(df_1.groupby('allocatedObjectClass').get_group('ByteString')['relativeSurvivedGCCycles'], stat="percent", bins=5)
plt.xlim(0, 105)
# Out:
# (0.0, 105.0)
