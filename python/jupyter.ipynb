# %%
from processor import *
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
# Load sampling 1
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-1/2024-02-13H20m39'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_1, metadata_df1 = load_df(csv_file, metadata_file)

# %%
# Relative frequency histogram
fig, axs = plt.subplots(ncols=3)
fig.suptitle("Relative frequencies histograms for DF", fontsize=16)


sns.histplot(df_1['relativeLifetime'] , stat="percent", bins=20, ax=axs[0]).set(xlabel='Relative lifetime', title='1% sampling')
sns.histplot(df_50['relativeLifetime'] , stat="percent", bins=20, ax=axs[1]).set(xlabel='Relative lifetime', title='50% sampling')
sns.histplot(df_100['relativeLifetime'] , stat="percent", bins=20, ax=axs[2]).set(xlabel='Relative lifetime', title='100% sampling')
# Out:
# [Text(0.5, 0, 'Relative lifetime'), Text(0.5, 1.0, '100% sampling')]

# %%
#By class

fig = plt.figure(1)
gridspec.GridSpec(3,3)

fig.suptitle("Relative frequencies by class for DF", fontsize=16)

top_allocated_classes = get_top_allocated_classes(df_1)


aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[0] ]
plt.subplot2grid((3,3), (0,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Relative lifetime', title=top_allocated_classes[0])

aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[1] ]
plt.subplot2grid((3,3), (0,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=5)
plot.set(xlim=(-5, 105), xlabel='Relative lifetime', title=top_allocated_classes[1])

aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[2] ]
plt.subplot2grid((3,3), (0,2))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Relative lifetime', title=top_allocated_classes[2])

aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[3] ]
plt.subplot2grid((3,3), (1,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=5)
plot.set(xlim=(-5, 105), xlabel='Relative lifetime', title=top_allocated_classes[3])

aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[4] ]
plt.subplot2grid((3,3), (1,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=5)
plot.set(xlim=(-5, 105), xlabel='Relative lifetime', title=top_allocated_classes[4])

plt.tight_layout()
plt.show()

# %%
gs = gridspec.GridSpec(3, 3)

for i in range(0, 6):
    if i < 3:
        ax = plt.subplot(gs[0, 2 * i:2 * i + 2])
    else:
        ax = plt.subplot(gs[1, 2 * i - 6:2 * i + 2 - 6])
    data = [[1, i * 1], [2, i * 2 * 2], [3, i * 3 * 3]]
    df = pd.DataFrame(data, columns=['x', 'y'])

    df.plot('x', 'y', ax=ax)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 5
#       3 for i in range(0, 6):
#       4     if i < 3:
# ----> 5         ax = plt.subplot(gs[0, 2 * i:2 * i + 2])
#       6     else:
#       7         ax = plt.subplot(gs[1, 2 * i - 6:2 * i + 2 - 6])
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/gridspec.py:257, in GridSpecBase.__getitem__(self, key)
#     254     except ValueError as err:
#     255         raise ValueError("Unrecognized subplot spec") from err
#     256     num1, num2 = np.ravel_multi_index(
# --> 257         [_normalize(k1, nrows, 0), _normalize(k2, ncols, 1)],
#     258         (nrows, ncols))
#     259 else:  # Single key
#     260     num1, num2 = _normalize(key, nrows * ncols, None)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/gridspec.py:237, in GridSpecBase.__getitem__.<locals>._normalize(key, size, axis)
# ...

# %%
print_table_allocations_average_lifetimes('DF sampling 1%', df_1, metadata_df1)
# Out:
# DF SAMPLING 1%
#
# Sampling rate: 1
# Total instances:  860027
# Total execution time: 53.430788
# Total full GCs:  18
# Total scavenges:  967
# ----------
# Allocated object class    Instances    Avg lifetime    Avg GC cycles    Avg Scavenges
# ------------------------  -----------  --------------  ---------------  ---------------
# Fraction                  27.91%       0.05%           0.01%            0.21%
# ReadStream                27.91%       0.05%           0.01%            0.21%
# NumberParser              27.91%       0.05%           0.01%            0.21%
# ByteString                13.95%       85.41%          77.15%           89.5%
# Array                     2.33%        85.41%          77.15%           89.5%

# %%
top_allocated_classes = get_top_allocated_classes(df_1)
aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[0] ]
plot = sns.histplot(aaa, x='relativeLifetime', hue='allocatedObjectClass', stat='percent', bins=5)
plot.set_xlim(-5, 105)
# Out:
# (-5.0, 105.0)

# %%
top_allocated_classes = get_top_allocated_classes(df_1)
aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[3] ]
plot = sns.histplot(aaa, x='relativeLifetime', hue='allocatedObjectClass', stat='percent', bins=6)
plot.set_xlim(-5, 105)
# Out:
# (-5.0, 105.0)

# %%
# Load sampling 100
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-100/2024-02-13H21m08'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_100, metadata_df100 = load_df(csv_file, metadata_file)

# %%
print_table_allocations_average_lifetimes('DF 100', df_100, metadata_df100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print_table_allocations_average_lifetimes('DF 100', df_100, metadata_df100)
#
# NameError: name 'df_100' is not defined

# %%
sns.histplot(df_100['relativeLifetime'] , stat="percent", bins=20).set(xlabel='Application relative lifetime', title='Relative frequencies for DF with 100% sampling')
# Out:
# [Text(0.5, 0, 'Application relative lifetime'),
#  Text(0.5, 1.0, 'Relative frequencies for DF with 100% sampling')]

# %%
# Load sampling 50
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-50/2024-02-13H20m41'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_50, metadata_df50 = load_df(csv_file, metadata_file)

# %%
print_table_allocations_average_lifetimes('DF 50', df_50, metadata_df50)
# Out:
# DF 50
#
# Sampling rate: 50
# Total instances:  43001470
# Total execution time: 79.053917
# Total full GCs:  26
# Total scavenges:  1037
# ----------
# Allocated object class    Instances    Avg lifetime    Avg GC cycles    Avg Scavenges
# ------------------------  -----------  --------------  ---------------  ---------------
# NumberParser              27.91%       0.05%           0.02%            0.19%
# Fraction                  27.91%       0.05%           0.02%            0.19%
# ReadStream                27.91%       0.05%           0.02%            0.19%
# ByteString                13.95%       89.79%          79.64%           90.21%
# Array                     2.33%        89.78%          79.64%           90.2%
