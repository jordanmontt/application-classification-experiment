# %%
from processor import *
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df_1, metadata_df1 = load_df('/Users/sebastian/Documents/PharoImages/new-2024/2024-01-25H12m32-df1.csv', '/Users/sebastian/Documents/PharoImages/new-2024/2024-01-25H12m32.json')

sns.histplot(df_1['relativeSurvivedGCCycles'], stat="percent", bins=20)
# Out:
# <Axes: xlabel='relativeSurvivedGCCycles', ylabel='Percent'>
