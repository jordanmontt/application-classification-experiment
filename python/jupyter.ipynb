# %%
from processor import *
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
# Load sampling 1
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-1/2024-02-13H20m39'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_1, metadata_df1 = load_df(csv_file, metadata_file)

# %%
# Relative frequency histogram
fig, axs = plt.subplots(ncols=3)
fig.suptitle("Lifetime frequencies for DF", fontsize=16)


sns.histplot(df_1['relativeLifetime'] , stat="percent", bins=20, ax=axs[0]).set(xlabel='Execution time', title='1% sampling')
sns.histplot(df_50['relativeLifetime'] , stat="percent", bins=20, ax=axs[1]).set(xlabel='Execution time', title='50% sampling')
sns.histplot(df_100['relativeLifetime'] , stat="percent", bins=20, ax=axs[2]).set(xlabel='Execution time', title='100% sampling')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       3 fig.suptitle("Lifetime frequencies for DF", fontsize=16)
#       6 sns.histplot(df_1['relativeLifetime'] , stat="percent", bins=20, ax=axs[0]).set(xlabel='Execution time', title='1% sampling')
# ----> 7 sns.histplot(df_50['relativeLifetime'] , stat="percent", bins=20, ax=axs[1]).set(xlabel='Execution time', title='50% sampling')
#       8 sns.histplot(df_100['relativeLifetime'] , stat="percent", bins=20, ax=axs[2]).set(xlabel='Execution time', title='100% sampling')
#
# NameError: name 'df_50' is not defined

# %%
#By class

fig = plt.figure(1)
gridspec.GridSpec(3,3)

fig.suptitle("Lifetime frequencies by class for DF with 100% sampling", fontsize=16)

top_allocated_classes = get_top_allocated_classes(df_50)


aaa = df_100.loc[ df_100['allocatedObjectClass'] == top_allocated_classes[0] ]
plt.subplot2grid((3,3), (0,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[0])

aaa = df_100.loc[ df_100['allocatedObjectClass'] == top_allocated_classes[1] ]
plt.subplot2grid((3,3), (0,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[1])

aaa = df_100.loc[ df_100['allocatedObjectClass'] == top_allocated_classes[2] ]
plt.subplot2grid((3,3), (0,2))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[2])

aaa = df_100.loc[ df_100['allocatedObjectClass'] == top_allocated_classes[3] ]
plt.subplot2grid((3,3), (1,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[3])

aaa = df_100.loc[ df_100['allocatedObjectClass'] == top_allocated_classes[4] ]
plt.subplot2grid((3,3), (1,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[4])

plt.tight_layout()
plt.show()

# %%
top_allocated_classes = get_top_allocated_classes(df_1)
aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[0] ]
plot = sns.histplot(aaa, x='relativeLifetime', hue='allocatedObjectClass', stat='percent', bins=5)
plot.set_xlim(-5, 105)
# Out:
# (-5.0, 105.0)

# %%
top_allocated_classes = get_top_allocated_classes(df_1)
aaa = df_1.loc[ df_1['allocatedObjectClass'] == top_allocated_classes[3] ]
plot = sns.histplot(aaa, x='relativeLifetime', hue='allocatedObjectClass', stat='percent', bins=6)
plot.set_xlim(-5, 105)
# Out:
# (-5.0, 105.0)

# %%
# Load sampling 100
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-100/2024-02-13H21m08'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_100, metadata_df100 = load_df(csv_file, metadata_file)

# %%
sns.histplot(df_100['relativeLifetime'] , stat="percent", bins=20).set(xlabel='Application relative lifetime', title='Relative frequencies for DF with 100% sampling')
# Out:
# [Text(0.5, 0, 'Application relative lifetime'),
#  Text(0.5, 1.0, 'Relative frequencies for DF with 100% sampling')]

# %%
# Load sampling 50
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-50/2024-02-13H20m41'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_50, metadata_df50 = load_df(csv_file, metadata_file)

# %% [markdown]
# # Actionable profilers

# %%
# Load actionable 1
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-100-actionable/2024-02-13H20m48'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_100_a, metadata_df100_a = load_df(csv_file, metadata_file)

# %%
#By class

fig = plt.figure(1)
gridspec.GridSpec(3,3)

fig.suptitle("Frequencies by class Actionable DF with 100% sampling", fontsize=16)

top_allocated_classes = get_top_allocated_classes(df_100_a)


aaa = df_100_a.loc[ df_100_a['allocatedObjectClass'] == top_allocated_classes[0] ]
plt.subplot2grid((3,3), (0,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[0])

aaa = df_100_a.loc[ df_100_a['allocatedObjectClass'] == top_allocated_classes[1] ]
plt.subplot2grid((3,3), (0,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[1])

aaa = df_100_a.loc[ df_100_a['allocatedObjectClass'] == top_allocated_classes[2] ]
plt.subplot2grid((3,3), (0,2))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[2])

aaa = df_100_a.loc[ df_100_a['allocatedObjectClass'] == top_allocated_classes[3] ]
plt.subplot2grid((3,3), (1,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[3])

aaa = df_100_a.loc[ df_100_a['allocatedObjectClass'] == top_allocated_classes[4] ]
plt.subplot2grid((3,3), (1,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[4])

plt.tight_layout()
plt.show()

# %%
print_table_allocations_average_lifetimes('Actionable 100', df_100_a, metadata_df100_a)
# Out:
# ACTIONABLE 100
#
# Sampling rate: 100
# Total instances:  86000606
# Total execution time: 256.481165
# Total full GCs:  32
# Total scavenges:  1389
# ----------
# Allocated object class    Instances    Avg lifetime    Avg GC cycles    Avg Scavenges
# ------------------------  -----------  --------------  ---------------  ---------------
# Fraction                  27.91%       62.44%          15.63%           41.99%
# NumberParser              27.91%       62.44%          15.63%           41.99%
# ReadStream                27.91%       62.44%          15.63%           41.99%
# ByteString                13.95%       96.74%          79.88%           92.69%
# Array                     2.33%        96.73%          79.88%           92.69%

# %%
# Load actionable 50
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-50-actionable/2024-02-13H20m32'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_50_a, metadata_df50_a = load_df(csv_file, metadata_file)

# %%
#By class

fig = plt.figure(1)
gridspec.GridSpec(3,3)

fig.suptitle("Frequencies by class Actionable DF with 50% sampling", fontsize=16)

top_allocated_classes = get_top_allocated_classes(df_50_a)


aaa = df_50_a.loc[ df_50_a['allocatedObjectClass'] == top_allocated_classes[0] ]
plt.subplot2grid((3,3), (0,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=6)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[0])

aaa = df_50_a.loc[ df_50_a['allocatedObjectClass'] == top_allocated_classes[1] ]
plt.subplot2grid((3,3), (0,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=6)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[1])

aaa = df_50_a.loc[ df_50_a['allocatedObjectClass'] == top_allocated_classes[2] ]
plt.subplot2grid((3,3), (0,2))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=6)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[2])

aaa = df_50_a.loc[ df_50_a['allocatedObjectClass'] == top_allocated_classes[3] ]
plt.subplot2grid((3,3), (1,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[3])

aaa = df_50_a.loc[ df_50_a['allocatedObjectClass'] == top_allocated_classes[4] ]
plt.subplot2grid((3,3), (1,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[4])

plt.tight_layout()
plt.show()

# %%
print_table_allocations_average_lifetimes('Actionable 50', df_50_a, metadata_df50_a)
# Out:
# ACTIONABLE 50
#
# Sampling rate: 50
# Total instances:  43001750
# Total execution time: 109.754536
# Total full GCs:  27
# Total scavenges:  1201
# ----------
# Allocated object class    Instances    Avg lifetime    Avg GC cycles    Avg Scavenges
# ------------------------  -----------  --------------  ---------------  ---------------
# NumberParser              27.91%       47.01%          12.18%           40.96%
# Fraction                  27.91%       47.01%          12.18%           40.96%
# ReadStream                27.91%       46.07%          11.93%           40.14%
# ByteString                13.95%       92.5%           80.65%           91.55%
# Array                     2.33%        92.49%          80.64%           91.54%

# %%
# Load actionable 1
parent_directory = '/Users/sebastian/Documents/PharoImages/illimani-rebench/data/sampling-1-actionable/2024-02-13H20m30'
csv_file = parent_directory + '.csv'
metadata_file = parent_directory + '.json'
# full_gcs_trace_file = parent_directory + '-full-gcs.csv'
# scavenges_trace_file = parent_directory + '-scavenges.csv'

df_1_a, metadata_df1_a = load_df(csv_file, metadata_file)

# %%
#By class

fig = plt.figure(1)
gridspec.GridSpec(3,3)

fig.suptitle("Frequencies by class actionable DF with 1% sampling", fontsize=16)

top_allocated_classes = get_top_allocated_classes(df_1_a)


aaa = df_1_a.loc[ df_1_a['allocatedObjectClass'] == top_allocated_classes[0] ]
plt.subplot2grid((3,3), (0,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[0])

aaa = df_1_a.loc[ df_1_a['allocatedObjectClass'] == top_allocated_classes[1] ]
plt.subplot2grid((3,3), (0,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[1])

aaa = df_1_a.loc[ df_1_a['allocatedObjectClass'] == top_allocated_classes[2] ]
plt.subplot2grid((3,3), (0,2))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=2)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[2])

aaa = df_1_a.loc[ df_1_a['allocatedObjectClass'] == top_allocated_classes[3] ]
plt.subplot2grid((3,3), (1,0))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[3])

aaa = df_1_a.loc[ df_1_a['allocatedObjectClass'] == top_allocated_classes[4] ]
plt.subplot2grid((3,3), (1,1))
plot = sns.histplot(aaa['relativeLifetime'] , stat="percent", bins=7)
plot.set(xlim=(-5, 105), xlabel='Execution time', title=top_allocated_classes[4])

plt.tight_layout()
plt.show()
